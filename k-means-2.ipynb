# %%
import os
import urllib.request

data_location = "../data/cars/mtcars_header.csv"
data_url = 'https://elephantscale-public.s3.amazonaws.com/data/cars/mtcars_header.csv'

if not os.path.exists (data_location):
    data_location = os.path.basename(data_location)
    if not os.path.exists(data_location):
        print("Downloading : ", data_url)
        urllib.request.urlretrieve(data_url, data_location)
print('data_location:', data_location)
import pandas as pd

dataset = pd.read_csv(data_location)
dataset.sample(10)
# Out:
# Downloading :  https://elephantscale-public.s3.amazonaws.com/data/cars/mtcars_header.csv
# data_location: mtcars_header.csv
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 29         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
#
#     gear  carb
# 3      3     1
# 29     5     6
# 4      3     2
# 15     3     4
# 23     3     4
# 13     3     3
# 31     4     2
# 27     5     2
# 12     3     3
# 30     5     8

# %%
"""
Now that we have ourselves a dataframe, let's work on turning it into vectors. We're going to vectorize 2 columns:

MPG
Number of cylinders.
"""
##create an smaller dataframe with just 'model', 'mpg', and 'cyl'
dataset2 = dataset [['model', 'mpg', 'cyl']]

## TODO : create our feature vector x by using 'mpg' and 'cyl' columns
## HINT : 'mpg', 'cyl'
x = dataset2[['mpg', 'cyl']]
x.sample(10)
import matplotlib.pyplot as plt
plt.scatter(x['mpg'], x['cyl'], marker='o')
plt.show()

# %%
"""
Now it's time to run kmeans on the resultant dataframe. We don't know what value of k to use, so let's just start with k=2. This means we will cluster into two groups.

We will fit a model to the data, and then train it.
"""
from sklearn.cluster import KMeans

## TODO: Instantiate K-means model with value k=2
## Hint : n_clusters=2
kmeans = KMeans(n_clusters=2, random_state=0)

model = kmeans.fit(x)

model
## TODO: calculate WSSSE by calling computeCost on dataframe
## Hint : inertia_
wssse = model.inertia_

print("k=2, wssse = ", wssse)
#The WSSSE for this is not particularly good. We will probably need to change k.

#Let's take a look at the transformed dataset. Notice the new column "prediction."
# Out:
# k=2, wssse =  416.48425120772936

# %%
## transform the dataset from the model
model.labels_ # these are the cluster ids
### TODO: Add new column to DF with cluster labels 
dataset2['cluster'] = model.labels_
print(dataset2)
# Out:
#                   model   mpg  cyl  cluster
# 0             Mazda RX4  21.0    6        0
# 1         Mazda RX4 Wag  21.0    6        0
# 2            Datsun 710  22.8    4        1
# 3        Hornet 4 Drive  21.4    6        0
# 4     Hornet Sportabout  18.7    8        0
# 5               Valiant  18.1    6        0
# 6            Duster 360  14.3    8        0
# 7             Merc 240D  24.4    4        1
# 8              Merc 230  22.8    4        1
# 9              Merc 280  19.2    6        0
# 10            Merc 280C  17.8    6        0
# 11           Merc 450SE  16.4    8        0
# 12           Merc 450SL  17.3    8        0
# 13          Merc 450SLC  15.2    8        0
# 14   Cadillac Fleetwood  10.4    8        0
# 15  Lincoln Continental  10.4    8        0
# 16    Chrysler Imperial  14.7    8        0
# 17             Fiat 128  32.4    4        1
# 18          Honda Civic  30.4    4        1
# 19       Toyota Corolla  33.9    4        1
# 20        Toyota Corona  21.5    4        0
# 21     Dodge Challenger  15.5    8        0
# 22          AMC Javelin  15.2    8        0
# 23           Camaro Z28  13.3    8        0
# 24     Pontiac Firebird  19.2    8        0
# 25            Fiat X1-9  27.3    4        1
# 26        Porsche 914-2  26.0    4        1
# 27         Lotus Europa  30.4    4        1
# 28       Ford Pantera L  15.8    8        0
# 29         Ferrari Dino  19.7    6        0
# 30        Maserati Bora  15.0    8        0
# 31           Volvo 142E  21.4    4        0
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#Notice what we have here. We have two clusters. One is smaller, fuel efficient cars like the Fiat and the Corolla (remember, we cluster on two variables only: MPG and cylinders). The other is for basically oll other cars. Probably, we can get better results here with a differnet value of k.

dataset2.sort_values(by=['cluster', 'mpg'])
# Out:
#                   model   mpg  cyl  cluster
# 14   Cadillac Fleetwood  10.4    8        0
# 15  Lincoln Continental  10.4    8        0
# 23           Camaro Z28  13.3    8        0
# 6            Duster 360  14.3    8        0
# 16    Chrysler Imperial  14.7    8        0
# 30        Maserati Bora  15.0    8        0
# 13          Merc 450SLC  15.2    8        0
# 22          AMC Javelin  15.2    8        0
# 21     Dodge Challenger  15.5    8        0
# 28       Ford Pantera L  15.8    8        0
# 11           Merc 450SE  16.4    8        0
# 12           Merc 450SL  17.3    8        0
# 10            Merc 280C  17.8    6        0
# 5               Valiant  18.1    6        0
# 4     Hornet Sportabout  18.7    8        0
# 9              Merc 280  19.2    6        0
# 24     Pontiac Firebird  19.2    8        0
# 29         Ferrari Dino  19.7    6        0
# 0             Mazda RX4  21.0    6        0
# 1         Mazda RX4 Wag  21.0    6        0
# 3        Hornet 4 Drive  21.4    6        0
# 31           Volvo 142E  21.4    4        0
# 20        Toyota Corona  21.5    4        0
# 2            Datsun 710  22.8    4        1
# 8              Merc 230  22.8    4        1
# 7             Merc 240D  24.4    4        1
# 26        Porsche 914-2  26.0    4        1
# 25            Fiat X1-9  27.3    4        1
# 18          Honda Civic  30.4    4        1
# 27         Lotus Europa  30.4    4        1
# 17             Fiat 128  32.4    4        1
# 19       Toyota Corolla  33.9    4        1

# %%
#Set K=3
from sklearn.cluster import KMeans

## TODO: Instantiate K-means model with value k=3
kmeans = KMeans(n_clusters=3, random_state=0)

model = kmeans.fit(x)

wssse = model.inertia_
print ("k=3, wssse =",wssse)
dataset2['cluster'] = model.labels_
dataset2.sort_values(by=['cluster', 'mpg'])
#This is a much better result for WSSSE (lower is better).
# Out:
# k=3, wssse = 169.4053571428571
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#                   model   mpg  cyl  cluster
# 14   Cadillac Fleetwood  10.4    8        0
# 15  Lincoln Continental  10.4    8        0
# 23           Camaro Z28  13.3    8        0
# 6            Duster 360  14.3    8        0
# 16    Chrysler Imperial  14.7    8        0
# 30        Maserati Bora  15.0    8        0
# 13          Merc 450SLC  15.2    8        0
# 22          AMC Javelin  15.2    8        0
# 21     Dodge Challenger  15.5    8        0
# 28       Ford Pantera L  15.8    8        0
# 11           Merc 450SE  16.4    8        0
# 12           Merc 450SL  17.3    8        0
# 26        Porsche 914-2  26.0    4        1
# 25            Fiat X1-9  27.3    4        1
# 18          Honda Civic  30.4    4        1
# 27         Lotus Europa  30.4    4        1
# 17             Fiat 128  32.4    4        1
# 19       Toyota Corolla  33.9    4        1
# 10            Merc 280C  17.8    6        2
# 5               Valiant  18.1    6        2
# 4     Hornet Sportabout  18.7    8        2
# 9              Merc 280  19.2    6        2
# 24     Pontiac Firebird  19.2    8        2
# 29         Ferrari Dino  19.7    6        2
# 0             Mazda RX4  21.0    6        2
# 1         Mazda RX4 Wag  21.0    6        2
# 3        Hornet 4 Drive  21.4    6        2
# 31           Volvo 142E  21.4    4        2
# 20        Toyota Corona  21.5    4        2
# 2            Datsun 710  22.8    4        2
# 8              Merc 230  22.8    4        2
# 7             Merc 240D  24.4    4        2

# %%
#Hyperparameter tuning
#Let's try iterating and plotting over values of k, so we can practice using the elbow method.

#Q ==> Why is WSSSE almost zero when k=32?

kvals = []
wssses = []

## TODO : Run k from 2 to 32
for k in range(2, 33):
    kmeans = KMeans(n_clusters=k, random_state=0)
    model = kmeans.fit(x)
    wssse = model.inertia_
    print ("k={},  wssse={}".format(k,wssse))
    kvals.append(k)
    wssses.append(wssse)
df = pd.DataFrame({'k': kvals, 'wssse':wssses})
df
# Out:
# k=2,  wssse=416.48425120772936
# k=3,  wssse=169.4053571428571
# k=4,  wssse=107.64864285714285
# k=5,  wssse=70.9895909090909
# k=6,  wssse=41.13829365079365
# k=7,  wssse=31.793055555555554
# k=8,  wssse=24.980222222222206
# k=9,  wssse=18.021388888888882
# k=10,  wssse=14.530555555555537
# k=11,  wssse=10.839999999999996
# k=12,  wssse=8.266666666666655
# k=13,  wssse=5.721666666666666
# k=14,  wssse=4.015000000000004
# k=15,  wssse=2.890000000000004
# k=16,  wssse=2.045000000000003
# k=17,  wssse=1.2836666666666687
# k=18,  wssse=0.7941666666666645
# k=19,  wssse=0.5583333333333325
# k=20,  wssse=0.43333333333333246
# k=21,  wssse=0.30833333333333246
# k=22,  wssse=0.22833333333333292
# k=23,  wssse=0.12166666666666705
# k=24,  wssse=0.07666666666666684
# k=25,  wssse=0.03166666666666662
# k=26,  wssse=0.005000000000000142
# k=27,  wssse=0.0
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: ConvergenceWarning: Number of distinct clusters (27) found smaller than n_clusters (28). Possibly due to duplicate points in X.
#   if sys.path[0] == '':
# k=28,  wssse=0.0
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: ConvergenceWarning: Number of distinct clusters (27) found smaller than n_clusters (29). Possibly due to duplicate points in X.
#   if sys.path[0] == '':
# k=29,  wssse=0.0
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: ConvergenceWarning: Number of distinct clusters (27) found smaller than n_clusters (30). Possibly due to duplicate points in X.
#   if sys.path[0] == '':
# k=30,  wssse=0.0
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: ConvergenceWarning: Number of distinct clusters (27) found smaller than n_clusters (31). Possibly due to duplicate points in X.
#   if sys.path[0] == '':
# k=31,  wssse=0.0
# k=32,  wssse=0.0
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: ConvergenceWarning: Number of distinct clusters (27) found smaller than n_clusters (32). Possibly due to duplicate points in X.
#   if sys.path[0] == '':
#      k       wssse
# 0    2  416.484251
# 1    3  169.405357
# 2    4  107.648643
# 3    5   70.989591
# 4    6   41.138294
# 5    7   31.793056
# 6    8   24.980222
# 7    9   18.021389
# 8   10   14.530556
# 9   11   10.840000
# 10  12    8.266667
# 11  13    5.721667
# 12  14    4.015000
# 13  15    2.890000
# 14  16    2.045000
# 15  17    1.283667
# 16  18    0.794167
# 17  19    0.558333
# 18  20    0.433333
# 19  21    0.308333
# 20  22    0.228333
# 21  23    0.121667
# 22  24    0.076667
# 23  25    0.031667
# 24  26    0.005000
# 25  27    0.000000
# 26  28    0.000000
# 27  29    0.000000
# 28  30    0.000000
# 29  31    0.000000
# 30  32    0.000000

# %%
# %matplotlib inline
from matplotlib import pyplot

## TODO: plot the values of k as the X axis versus the costs (WSSSE) as the y axis
## Hint  : x=kvals,  y=wssses
pyplot.plot(kvals, wssses)
pyplot.show()
#Using the Elbow method, what would be a good value of k?

# %%
from  sklearn.metrics import silhouette_score

# Let's loop through a few ranges
sil_scores = []

for k in range(2, 15):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(x)
    y_pred = kmeans.predict(x)
    sil_score = silhouette_score (x, y_pred)
    tmp = {'x': k, 'y': sil_score}
    sil_scores.append(tmp)
    print ("silhoutte_score : ", sil_score)
# Out:
# silhoutte_score :  0.5611330508779442
# silhoutte_score :  0.5580381626394326
# silhoutte_score :  0.5109237412060313
# silhoutte_score :  0.5508165664375504
# silhoutte_score :  0.5731070080129879
# silhoutte_score :  0.5494264138529918
# silhoutte_score :  0.5692480016111076
# silhoutte_score :  0.6060322759356979
# silhoutte_score :  0.6278557799318625
# silhoutte_score :  0.5478924072082803
# silhoutte_score :  0.5578731418951062
# silhoutte_score :  0.6376103921827546
# silhoutte_score :  0.6532445552159384

# %%
import pandas as pd
df = pd.DataFrame(sil_scores)
import seaborn as sns
sns.lineplot(x ='x', y='y', data=df )
pyplot.show()

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

df = pd.read_csv('https://raw.githubusercontent.com/fenago/DSBook/main/Chapter%2010%20-%20Analyzing%20a%20Dataset/Datasets/bikes.csv', index_col=0)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered  count
# datetime
# 2011-01-01 00:00:00        81        0.0       3          13     16
# 2011-01-01 01:00:00        80        0.0       8          32     40
# 2011-01-01 02:00:00        80        0.0       5          27     32
# 2011-01-01 03:00:00        75        0.0       3          10     13
# 2011-01-01 04:00:00        75        0.0       0           1      1

# %% [markdown]
# 1. Download and load the dataset into Python using .read_csv().
# 2. Explore the structure and content of the dataset by using .shape, .dtypes, .head(), .tail(), or      .sample().
# 3. Calculate and interpret descriptive statistics with .describe().
# 4. Analyze each variable using data visualization with bar charts, histograms, or boxplots.
# 5. Identify areas that need clarification from the marketing department and potential data quality issues.

# %%
df.shape
# Out:
# (10886, 11)

# %%
df.dtypes
# Out:
# season          int64
# holiday         int64
# workingday      int64
# weather         int64
# temp          float64
# atemp         float64
# humidity        int64
# windspeed     float64
# casual          int64
# registered      int64
# count           int64
# dtype: object

# %%
df.sample(5)
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2012-07-06 16:00:00       3        0           1        1  37.72  40.910
# 2011-12-10 04:00:00       4        0           0        2  10.66  13.635
# 2011-10-09 14:00:00       4        0           0        1  27.88  31.820
# 2012-04-03 11:00:00       2        0           1        1  19.68  23.485
# 2011-05-13 02:00:00       2        0           1        2  20.50  24.240
#
#                      humidity  windspeed  casual  registered  count
# datetime
# 2012-07-06 16:00:00        29     7.0015      69         300    369
# 2011-12-10 04:00:00        65     7.0015       0           3      3
# 2011-10-09 14:00:00        47    11.0014     272         228    500
# 2012-04-03 11:00:00        23     0.0000      91         167    258
# 2011-05-13 02:00:00        88     8.9981       3           8     11

# %%
df.isna().any()
# Out:
# season        False
# holiday       False
# workingday    False
# weather       False
# temp          False
# atemp         False
# humidity      False
# windspeed     False
# casual        False
# registered    False
# count         False
# dtype: bool

# %%
df.describe().T
# Out:
#               count        mean         std   min      25%      50%       75%  \
# season      10886.0    2.506614    1.116174  1.00   2.0000    3.000    4.0000
# holiday     10886.0    0.028569    0.166599  0.00   0.0000    0.000    0.0000
# workingday  10886.0    0.680875    0.466159  0.00   0.0000    1.000    1.0000
# weather     10886.0    1.418427    0.633839  1.00   1.0000    1.000    2.0000
# temp        10886.0   20.230860    7.791590  0.82  13.9400   20.500   26.2400
# atemp       10886.0   23.655084    8.474601  0.76  16.6650   24.240   31.0600
# humidity    10886.0   61.886460   19.245033  0.00  47.0000   62.000   77.0000
# windspeed   10886.0   12.799395    8.164537  0.00   7.0015   12.998   16.9979
# casual      10886.0   36.021955   49.960477  0.00   4.0000   17.000   49.0000
# registered  10886.0  155.552177  151.039033  0.00  36.0000  118.000  222.0000
# count       10886.0  191.574132  181.144454  1.00  42.0000  145.000  284.0000
#
#                  max
# season        4.0000
# holiday       1.0000
# workingday    1.0000
# weather       4.0000
# temp         41.0000
# atemp        45.4550
# humidity    100.0000
# windspeed    56.9969
# casual      367.0000
# registered  886.0000
# count       977.0000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='season', data=df, kind='count')

# %%
df.columns
# Out:
# Index(['season', 'holiday', 'workingday', 'weather', 'temp', 'atemp',
#        'humidity', 'windspeed', 'casual', 'registered', 'count'],
#       dtype='object')

# %%
p = sns.scatterplot(y="holiday", x = 'datetime',data = df)

# %%
p = sns.scatterplot(y="workingday", x = 'datetime', data = df)

# %%
sns.scatterplot(y="weather", x = 'datetime', data = df)
# Out:
# <AxesSubplot:xlabel='datetime', ylabel='weather'>

# %%
sns.lineplot(y="temp", x = 'datetime', data = df)
# Out:
# <AxesSubplot:xlabel='datetime', ylabel='temp'>

# %%
sns.lineplot(y="atemp", x = 'datetime', data = df)
# Out:
# <AxesSubplot:xlabel='datetime', ylabel='atemp'>

# %%
sns.lineplot(y="humidity", x = 'datetime', data = df)
# Out:
# <AxesSubplot:xlabel='datetime', ylabel='humidity'>

# %%
sns.lineplot(y="windspeed", x = 'datetime', data = df)
# Out:
# <AxesSubplot:xlabel='datetime', ylabel='windspeed'>

# %%
sns.scatterplot(y="windspeed", x = 'datetime',data = df)
# Out:
# <AxesSubplot:xlabel='datetime', ylabel='windspeed'>

# %%
sns.lineplot(y="casual", x = 'datetime', data = df)
# Out:
# <AxesSubplot:xlabel='datetime', ylabel='casual'>

# %%
sns.scatterplot(y="casual", x = 'datetime',data = df)
# Out:
# <AxesSubplot:xlabel='datetime', ylabel='casual'>

# %%
sns.lineplot(y="registered", x = 'datetime', data = df)
# Out:
# <AxesSubplot:xlabel='datetime', ylabel='registered'>

# %%
sns.scatterplot(y="registered", x = 'datetime',data = df)
# Out:
# <AxesSubplot:xlabel='datetime', ylabel='registered'>

# %%
sns.lineplot(y="count", x = 'datetime', data = df)
# Out:
# <AxesSubplot:xlabel='datetime', ylabel='count'>

# %%
sns.scatterplot(y="count", x = 'datetime',data = df)
# Out:
# <AxesSubplot:xlabel='datetime', ylabel='count'>
